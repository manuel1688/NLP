# %% [markdown]
# # Ejemplo: Clasificación de textos con embeddings semánticos y 20 Newsgroups
#
# Este notebook muestra cómo usar SentenceTransformer para obtener embeddings semánticos a partir de los textos del dataset 20newsgroups y entrenar un clasificador LogisticRegression sobre esos vectores.

# %% [markdown]
# ## 1. Importar librerías necesarias

# %%
from sklearn.datasets import fetch_20newsgroups
from sentence_transformers import SentenceTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %% [markdown]
# ## 2. Cargar el dataset 20 Newsgroups

# %%
# Cargar los datos de entrenamiento y prueba
train = fetch_20newsgroups(subset='train', remove=('headers', 'footers', 'quotes'))
test = fetch_20newsgroups(subset='test', remove=('headers', 'footers', 'quotes'))

# %% [markdown]
# ## 3. Obtener embeddings semánticos para cada texto

# %%
encoder = SentenceTransformer('all-MiniLM-L6-v2')
X_train = encoder.encode(train.data, show_progress_bar=True)
X_test = encoder.encode(test.data, show_progress_bar=True)

# %% [markdown]
# ## 4. Entrenar un clasificador LogisticRegression

# %%
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, train.target)

# %% [markdown]
# ## 5. Evaluar el modelo y mostrar métricas

# %%
y_pred = clf.predict(X_test)
print(classification_report(test.target, y_pred, target_names=test.target_names))
